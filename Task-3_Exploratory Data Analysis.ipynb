# %% [markdown]
# <font color='blue'>
#
# # Rekha Meena
#
# # @The Sparks Foundation
#
# # Data Science & Business Analytics Intern
#
#
# # Task-3 : Exploratory Data Analysis - Retail
#
#
# ## Problem Statement :
#
# - Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# - As a business manager, try to find out the weak areas where you can work to make more profit.
# - What all business problems you can derive by exploring the data? </font>
#
# ## Dataset: https://bit.ly/3i4rbWl

# %% [markdown]
# # <span style="color:blue">Exploratory data analysis (EDA) : </span>
# - A  term for certain kinds of initial analysis and findings done with data sets, usually early on in an analytical process. Some experts describe it as “taking a peek” at the data to understand more about what it represents and how to apply it.

# %%
# ignore warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Libraries !!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
print(df['Ship Mode'].unique())
print(df['Segment'].unique())
print(df['Country'].unique())
print(df['Region'].unique())
print(df['Category'].unique())
print(df['Sub-Category'].unique())
print(df['Sales'].unique())
print(df['Quantity'].unique())
print(df['Discount'].unique())
print(df['Profit'].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['South' 'West' 'Central' 'East']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# [261.96  731.94   14.62  ... 437.472  97.98  243.16 ]
# [ 2  3  5  7  4  6  9  1  8 14 11 13 10 12]
# [0.   0.45 0.2  0.8  0.3  0.5  0.7  0.6  0.32 0.1  0.4  0.15]
# [ 41.9136 219.582    6.8714 ...  16.124    4.1028  72.948 ]

# %% [markdown]
# # Exploratory Data Analysis
# Let's begin some exploratory data analysis! We'll start by checking out missing data!

# %% [markdown]
# # Missing Data
# We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
df.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %% [markdown]
# #### Here all entries is not see now, apply sum all the null value.

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Plot the figure find the null value

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### <span style="color:green">Figure cleally show dataset is not having any null value, so no need of Data Cleaning.</span>

# %% [markdown]
# # Let's continue on by visualizing some more of the data!

# %% [markdown]
# ## Find outliers using the basic 3 standard deviations approach:
# - Method: Any point outside of 3 standard deviations would be an outlier.
# - We find the z score for each of the data point in the dataset and if the z score is greater than 3 than we can classify that point as an outlier.

# %%
# Define the outlier function
def detect_outlier(data):
    outliers = []
    threshold = 3
    mean = np.mean(df[data])
    std = np.std(df[data])
    
    for x in df[data]:
        z_score = (x - mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(x)
        return outliers
    
    
# Define the function to display outliers 
def display_outlier(feature):
    outlier_list = detect_outlier(feature)
    if not outlier_list:
        print(feature+" = NO outliers that are above 3 s.d.")
    else:
        print(feature+"'s outliers are'"+" | ".join(outlier_list))
        

# Display the outliers
for x in ['Postal Code', 'Sales', 'Quantity', 'Discount','Profit']:
    display_outlier(x)
# Out:
# Postal Code = NO outliers that are above 3 s.d.
# Sales = NO outliers that are above 3 s.d.
# Quantity = NO outliers that are above 3 s.d.
# Discount = NO outliers that are above 3 s.d.
# Profit = NO outliers that are above 3 s.d.

# %% [markdown]
# # Find out Outlier Using Boxplot

# %%
for feature in ['Postal Code', 'Sales', 'Quantity', 'Discount','Profit']:
    data=df.copy()
    data[feature]=np.log(data[feature])
    data.boxplot(column=feature,grid = True)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# #   <span style="color:purple">Observation : The Postal Code, Sales, Discount and Profit having outlier Dataset</span>

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D8A9C7F208>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(df['Sales'], color='green',label='Sales',shade=True, bw=50)
sns.kdeplot(df['Profit'],color='orange',label='Profit',shade=True,bw=50)
plt.xlim([0, 1000])
plt.legend()

# %% [markdown]
# # Relation between Ship Mode and Profit.

# %%
plt.scatter(data = df, x= 'Discount', y='Profit')

# %%
plt.scatter(data = df, x= 'Sales', y='Profit')

# %%
plt.figure(figsize=(14,4))
sns.set(font_scale =1,palette = "viridis")
sns.barplot(data = df, x="Ship Mode",y="Profit",hue="Category")
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Discount',data=df, saturation=0.75, palette='rainbow')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['State'])
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
# Out:
# Text(0.5,1,'State')

# %%
plt.figure(figsize=(10,7))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5,1,'Sub-Category')

# %%
plt.figure(figsize=(18,5))
sns.countplot(df['Quantity'])
plt.title('Quantity',fontsize=20)
# Out:
# Text(0.5,1,'Quantity')

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'], saturation=0.75, palette='rainbow',ax=axs[0][0])
axs[0][0].set_title('Category',fontsize=20)

sns.countplot(df['Segment'], saturation=0.75, palette='rainbow',ax=axs[0][1])
axs[0][1].set_title('Segment',fontsize=20)

sns.countplot(df['Ship Mode'],saturation=0.75, palette='rainbow' ,ax=axs[1][0])
axs[1][0].set_title('Ship Mode',fontsize=20)

sns.countplot(df['Region'],saturation=0.75, palette='rainbow' ,ax=axs[1][1])
axs[1][1].set_title('Region',fontsize=20)

plt.tight_layout()

# %%
df['Sales'].hist(color='green',bins=40,figsize=(8,4))

# %% [markdown]
# # <span style="color:Blue">Find the correlation</span>

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(), cmap = 'rocket_r', annot=True)

# %% [markdown]
# ## Observation :
# - Profit and Postal Code are Negatively Correlated.
# - Profit and Sales are Positively Correlated.
# - Quantity and Profit are less Moderately Correlated.
# - Profit and Discount are Negatively Correlated.

# %%
sns.pairplot(df,hue='Category')

# %%
sns.pairplot(df,hue='Region')

# %% [markdown]
# # <span style = "color:blue">Distribution of feature: </span>

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.distplot(df['Sales'], color = 'purple',  ax = axs[0][0])
sns.distplot(df['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(df['Quantity'], color = 'red',  ax = axs[1][0])
sns.distplot(df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
# Out:
# Text(0.5,1,'Discount Distribution')

# %% [markdown]
# # Find the information among Profit, Discount and Sales
# # - <span style="color:orange">based on Sub-Category.</span>

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)

# %% [markdown]
# ## Observation :
# - Copiers sub-Category give the highest sales

# %%
plt.figure(figsize = (20,20))
plt.pie(df_sub_category['Profit'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Profit Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
# Out:
# (array([], dtype=float64), <a list of 0 Text xticklabel objects>)

# %% [markdown]
# # Observation :
# - The weak area in the Sub Categories are Binders,Paper,Phones,Storage, Art, Appliances, Bookcases,Fasteners.

# %% [markdown]
# # - <span style="color:orange">based on Category.</span>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df_category= df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category.head()
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %% [markdown]
# # Based on Category find the inside in the Profit :

# %%
df_ctgy=df_category.sort_values('Profit')

df_ctgy[['Profit']].plot(kind = 'bar', color='yellow', figsize = (15,4))
plt.title('Category wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Category')
plt.xlabel('Category')
# Out:
# Text(0.5,0,'Category')

# %%
df_state['Profit'].plot(kind='pie',
                        figsize = (5,5),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('Category wise analysis of Profit',fontsize=20)
# Out:
# Text(0.5,1,'Category wise analysis of Profit')

# %% [markdown]
# # Observation :
# ### <span style="color:blue">Category wise analysis of Profit - </span>
# -  Furniture = 8.1%%
# -  Technology = 18.9%
# -  Office Supplies = 73.1%
#
# ### Technology give the highest profit

# %% [markdown]
# # Based on Category find the inside in the Sales :

# %%
df_ctgy=df_category.sort_values('Sales')

df_ctgy[['Sales']].plot(kind = 'bar', color='green', figsize = (15,4))
plt.title('Category wise Profit Analysis', fontsize = 20)
plt.ylabel('Sales per Category')
plt.xlabel('Category')
# Out:
# Text(0.5,0,'Category')

# %%
df_state['Sales'].plot(kind='pie',
                        figsize = (5,5),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('Category wise analysis of Sale',fontsize=20)
# Out:
# Text(0.5,1,'Category wise analysis of Sale')

# %% [markdown]
# # Observation :
# ### Category wise analysis of Sales-
# - Furniture = 37.9%
# - Technology = 49.1%
# - Office Supplies = 12.9%
#
# ###  <span style = "color :red"> Technology Category material Sales is High, but Office Supplies are weak areas if we work on office area then Profit will be increase.</span>

# %% [markdown]
# # Analysis Profit States wise :

# %%
df_state1 = df['State'].value_counts()
df_state1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df_state1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# # Observation :
# ### Here we can see Highest Sales in -
# - California, New York and Texas
# ### If we increase the Sales in below mention States then Chance to increase the Profit.
#
# - Idaho ,Montana, South Dakota, Vermont, District of Columbia,Maine, North Dakota, West Virginia ,Wyoming

# %%
df_state1.head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %% [markdown]
# # Find the Profit in each state :

# %%
df_state2=df_state.sort_values('Profit')

df_state2[['Profit']].plot(kind = 'bar', figsize = (15,4))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# # Observation :
# ### <Span style = "color:orange" > Vermont State is give the highest Profit but Ohio State is the Lowest Profit.</span>

# %% [markdown]
# ##  Find the Sales of each State.

# %%
df_state['Sales'].plot(kind='pie',
                        figsize = (20,20),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise analysis of Sale',fontsize=20)
# Out:
# Text(0.5,1,'State wise analysis of Sale')

# %% [markdown]
# # Observation :
# - Highest amount of sales= Wyoming(11.8%)
# - Lowest amount of sales= South Dakota(0.8%)

# %% [markdown]
# # Find out the Weak Area Citywise

# %%
df_city= df.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
df_city = df_city.sort_values('Profit')
df_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %% [markdown]
# # <span style = "color:blue"> Low Profit using head().</span>

# %%
df_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color = 'green')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5,1,'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# # <span style = "color:blue"> High Profit using tail().</span>

# %%
df_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color = 'green')
plt.title('City wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5,1,'City wise analysis of Sale, Discount, profit')

# %% [markdown]
# # Observation :
# ### 30 CITIES WHICH HAS PROFIT IN POSITIVE, 30 CITIES WHICH HAS PROFIT IN NEGATIVE

# %% [markdown]
# # QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS

# %%
df_quantity = df.groupby(['Quantity'])[['Profit', 'Sales', 'Discount']].mean()
df_quantity
# Out:
#               Profit        Sales  Discount
# Quantity
# 1           8.276396    59.234632  0.152959
# 2          16.006831   120.354488  0.154858
# 3          23.667715   175.201578  0.153329
# 4          37.131310   271.764059  0.157708
# 5          40.257394   337.936339  0.157146
# 6          18.051517   362.101960  0.166556
# 7          56.579163   395.888393  0.161980
# 8          42.244342   458.210802  0.171595
# 9          68.557716   498.083683  0.147946
# 10         35.862404   422.046737  0.190702
# 11        126.275503   463.896529  0.097059
# 12         51.524609   646.452522  0.113043
# 13        235.144481  1197.710704  0.157407
# 14         93.931166   452.826138  0.151724

# %% [markdown]
# # Observation :
# - Weak area in Quality is Quality 1, 2,3,6,4,10,5,8 all are give less than 50% profit.
# - The highest Quality is 13.

# %%
df_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(15, 15),
                    pctdistance=0.80,
                    startangle=90,     
                    shadow=True,
                    labels = df_quantity.index)
plt.title('Quantity wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5,1,'Quantity wise analysis of Sale, Discount, profit')

# %% [markdown]
# # Segment wise analysis of Profit and sales

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# # Observation :
# - <span style="color:blue">The Weak area inside the Segmant is Consumer</span>

# %%
df_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(8, 8),
                    startangle=90,     
                    shadow=True,
                    labels = df_segment.index)
plt.title('Segment wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5,1,'Segment wise analysis of Sale, Discount, profit')

# %% [markdown]
# # Region wise analysis of Profit and sales

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df_Region= df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_Region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
df_Region['Profit'].plot(kind='bar',figsize=(15,5),color = 'green')
plt.title('City wise analysis of profit')
# Out:
# Text(0.5,1,'City wise analysis of profit')

# %% [markdown]
# # Observation:
# - <span style = "color:blue"> The weak area inside the Region is Central. </span>

# %% [markdown]
# # <span style = "color:blue"> CONCLUTION :- </span>
#
# - Profit is more than that of sale but there are some areas where profit could be increased.
#
#
# ## <span style = "color:green">As a business manager, try to find out the weak areas where you can work to make more profit.  </span>
# - The weak area inside the Region is Central.
# - The Weak area inside the Segmant is Consumer.
# - Weak area in Quality is Quality 1, 2,3,6,4,10,5,8 all are give less than 50% profit.
# - 30 CITIES WHICH HAS PROFIT IN NEGATIVE
# - Ohia, colorado, North Carlina, Tennessee, Pennsyvania, Texas, Illinois, Arizona, Oregon, and Florida States sales in Loss.
# - If we increase the Sales in below mention States then Chance to increase the Profit.
#     - Idaho ,Montana, South Dakota, Vermont, District of Columbia,Maine, North Dakota, West Virginia ,Wyoming
#
# - In the Category analysis Office Supplies profit = 12.9%, it's weak areas if we work on office area then Profit will be increase.
#
# - The weak area in the Sub Categories are Binders,Paper,Phones,Storage, Art, Appliances, Bookcases,Fasteners.
#
#
# ## <span style = "color:green">What all business problems you can derive by exploring the data? </span>
# -  Stores located in urban or Tier 1 cities and densely populated areas should have higher sales because of the higher income levels of people there.
# -  Stores located in rural areas should have lower sales because of less demand.
# -  Quality (Branded) products should have higher sales because of higher trust in the customer.
# -  Products accompanied with attractive offers and discounts is not impact on sell, after perform the analysis
#
# # <span style = "color:blue">THANK YOU !!</span>
